# %%
import numpy as np 
import pandas as pd

import utils 

import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
subj = utils.ExpInfo.getSubjIDs()[0]
task = utils.ExpInfo.taskName[0]

# %%
x_, h_, y_ = utils.LoadData.xhy(subj, task)

# %%
nBatch = 128
x = np.random.normal(scale=0.01, size=(nBatch, 60, 2))
# x = x.cumsum(axis=1)
plt.plot(x[0, :, 0].cumsum(), x[0, :, 1].cumsum())

# %%
h, y = utils.Model.quick_forward(subj, x)

# %%
pca = utils.Analysis.pca(h, plot_explained_variance=True)
pca.explained_variance_ratio_
# Out:
# array([0.43939199, 0.26566594, 0.07582271, 0.04536065, 0.03449382,
#        0.03370684, 0.02587856, 0.01761496, 0.01541526, 0.01170069,
#        0.01062817, 0.00726148, 0.00621078, 0.00525935, 0.00354335,
#        0.00204543])

# %%
pca = utils.Analysis.pca(h_[10], plot_explained_variance=True)
pca.explained_variance_ratio_
# Out:
# array([0.29134687, 0.18526207, 0.11716593, 0.10510201, 0.07428268,
#        0.05578885, 0.04887393, 0.03527683, 0.02720063, 0.02035077,
#        0.01390462, 0.0118322 , 0.0070293 , 0.00436967, 0.00164245,
#        0.00057118])
